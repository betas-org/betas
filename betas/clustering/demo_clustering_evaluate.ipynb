# %% [markdown]
# ## In this notebook we create a dataset, which originally comprises of 10 clusters and then run our clustering algo (based on kmeans++) to evaluate the most optimal number of clusters into which the dataset could be divided using the inertia/objective-value as the metric

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y = make_blobs(n_samples=10000, centers=10, n_features=300,
                  cluster_std=0.001, random_state=0)

# %%
import clustering_evaluate
fig, opt_clusters = clustering_evaluate.kmeans_viz_and_opt_clusters(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-57487845c410> in <module>
#       1 import clustering_evaluate
# ----> 2 fig, opt_clusters = clustering_evaluate.kmeans_viz_and_opt_clusters(X)
#
# ~/git/515project/betas/betas/clustering/clustering_evaluate.py in kmeans_viz_and_opt_clusters(input_features)
#     114     obj_vals = get_cost_from_kmeans(n_clusters_vector, input_features)
#     115
# --> 116     plt_clust = visualize_kmeans(n_clusters_vector, obj_vals)
#     117     optimal_num_clusters = get_optimal_num_clusters(n_clusters_vector,
#     118                                                     obj_vals)
#
# ~/git/515project/betas/betas/clustering/clustering_evaluate.py in visualize_kmeans(n_clusters_vector, obj_vals)
#      73     axx.plot(n_clusters_vector, obj_vals, c=color)
#      74
# ---> 75     plt.title('Objective value from K-means++ vs. Number of Clusters')
#      76     plt.tight_layout()
#      77     return fig
#
# TypeError: 'Text' object is not callable

# %%
opt_clusters

# %%
fig
