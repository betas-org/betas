# %%
import seaborn as sns

# import iris data
iris = sns.load_dataset("iris")

# %%
from regression_analysis_plot import matrix_plot

matrix_plot(iris, 'species')

# %%
from regression_analysis_plot import corr_heatmap
    
corr_heatmap(iris)

# %%
from regression_analysis_plot import reg_plot

reg_plot(iris, 'sepal_length', 'petal_length')

# %%
from regression_analysis_plot import reg

x = iris[iris.columns[:3]]
y = iris[iris.columns[3:4]]
fit = reg(x,y)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            petal_width   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     734.4
# Date:                Mon, 20 May 2019   Prob (F-statistic):           7.83e-88
# Time:                        22:48:57   Log-Likelihood:                 36.751
# No. Observations:                 150   AIC:                            -65.50
# Df Residuals:                     146   BIC:                            -53.46
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -0.2403      0.178     -1.347      0.180      -0.593       0.112
# ...

# %%
from regression_analysis_plot import resid_plot

resid_plot(iris, fit, 'petal_width')
